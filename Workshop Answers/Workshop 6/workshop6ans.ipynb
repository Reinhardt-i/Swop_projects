# %% [markdown]
# ### Exercise 1

# %%
temperatures = [-1.3, 0.1, 2.1, 2.0, 1.5, 0.3, 0.2, 0.8, 0.1, -0.1, -0.9, -1.0, 0.5]
filtered_temperatures = [temp for temp in temperatures if temp <= 0]
print(filtered_temperatures)
# Out:
# [-1.3, -0.1, -0.9, -1.0]

# %% [markdown]
# ### Exercise 2

# %%
stocks = {
    "UWMC": {"price": 6.98, "market_cap": 0.7, "pe_ratio": 1.2},
    "QRTEA": {"price": 10.36, "market_cap": 4.2, "pe_ratio": 3.1},
    "SAGE": {"price": 41.42, "market_cap": 2.4, "pe_ratio": 3.3},
    "NLY": {"price": 8.69, "market_cap": 12.6, "pe_ratio": 3.8},
    "SLVM": {"price": 27.64, "market_cap": 1.2, "pe_ratio": 4.2},
}


filtered_stocks = {
    symbol: info for symbol, info in stocks.items()
    if info["pe_ratio"] > 2 and info["market_cap"] > 5
}

print(filtered_stocks)
# Out:
# {'NLY': {'price': 8.69, 'market_cap': 12.6, 'pe_ratio': 3.8}}

# %% [markdown]
# ### Exercise 2 part 2

# %%
num_cube_lc = [n**3 for n in range(1, 11) if n % 2 == 0]
num_cube_generator = (num**3 for num in range(1, 11) if num % 2 == 0)

list_comp_result = f"List Comprehension = {num_cube_lc}\n"
generator_exp_result = f"Generator Expression = {num_cube_generator}\n"

sum_result = f"Sum = {sum(num_cube_generator)}\n"
print(list_comp_result, generator_exp_result, sum_result)
# Out:
# List Comprehension = [8, 64, 216, 512, 1000]
#  Generator Expression = <generator object <genexpr> at 0x106e497d0>
#  Sum = 1800

# %%
print([n**3 for n in range(1, 10*1000) if n % 2 == 0])
# Out:
# [8, 64, 216, 512, 1000, 1728, 2744, 4096, 5832, 8000, 10648, 13824, 17576, 21952, 27000, 32768, 39304, 46656, 54872, 64000, 74088, 85184, 97336, 110592, 125000, 140608, 157464, 175616, 195112, 216000, 238328, 262144, 287496, 314432, 343000, 373248, 405224, 438976, 474552, 512000, 551368, 592704, 636056, 681472, 729000, 778688, 830584, 884736, 941192, 1000000, 1061208, 1124864, 1191016, 1259712, 1331000, 1404928, 1481544, 1560896, 1643032, 1728000, 1815848, 1906624, 2000376, 2097152, 2197000, 2299968, 2406104, 2515456, 2628072, 2744000, 2863288, 2985984, 3112136, 3241792, 3375000, 3511808, 3652264, 3796416, 3944312, 4096000, 4251528, 4410944, 4574296, 4741632, 4913000, 5088448, 5268024, 5451776, 5639752, 5832000, 6028568, 6229504, 6434856, 6644672, 6859000, 7077888, 7301384, 7529536, 7762392, 8000000, 8242408, 8489664, 8741816, 8998912, 9261000, 9528128, 9800344, 10077696, 10360232, 10648000, 10941048, 11239424, 11543176, 11852352, 12167000, 12487168, 12812904, 13144256, 13481272, 13824000, 14172488, 14526784, 14886936, 15252992, 15625000, 16003008, 16387064, 16777216, 17173512, 17576000, 17984728, 18399744, 18821096, 19248832, 19683000, 20123648, 20570824, 21024576, 21484952, 21952000, 22425768, 22
# %% [markdown]
# ### Exercise 4

# %% [markdown]
# #### Calculating Wasted Space -
#
#
# - The SQL query to get the maximum length of data stored in each varchar field :
# ```sql
#
# SELECT
#   MAX(LENGTH(id)) AS MaxIdLength,
#   MAX(LENGTH(phone)) AS MaxPhoneLength,
#   MAX(LENGTH(name)) AS MaxNameLength,
#   MAX(LENGTH(email)) AS MaxEmailLength,
#   MAX(LENGTH(address)) AS MaxAddressLength,
#   MAX(LENGTH(country)) AS MaxCountryLength,
#   MAX(LENGTH(region)) AS MaxRegionLength,
#   MAX(LENGTH(postalzip)) AS MaxPostalZipLength,
#   MAX(LENGTH(token)) AS MaxTokenLength
# FROM gameUser;
#
#
# ```
#
# - The SQL query for the allocated space for each varchar field :
# ```sql
#
# SELECT
#   COLUMN_NAME,
#   CHARACTER_MAXIMUM_LENGTH
# FROM information_schema.COLUMNS
# WHERE
#   TABLE_NAME = 'gameUser' AND
#   TABLE_SCHEMA = 'cetm50' AND
#   DATA_TYPE = 'varchar';
#
#
# ```
#
# We can calculate the wasted space for each field like this:
#
# 1. Calculate the wasted space for each field per record by subtracting the maximum used length from the allocated space.
# 2. Multiply the wasted space per record by the number of records to find the total wasted space for that field.
#
#
# The calculated wasted space for each varchar field in the database, as well as the total wasted space, is as follows (in bytes):
#
# - Phone: 571,704 bytes
# - Name: 1,584,240 bytes
# - Email: 1,542,912 bytes
# - Address: 1,343,160 bytes
# - Country: 337,512 bytes
# - Region: 199,752 bytes
# - Postalzip: 6,888 bytes
# - Token: 1,708,224 bytes
#
# **Total wasted space across all varchar fields for all records is 7,294,392 bytes, which is approximately 7,123.43 kilobytes (or about 6.96 megabytes).**

# %% [markdown]
# ### Exercise 5

# %% [markdown]
# *Checked out the links, and noted SQL things I didn't know*

# %% [markdown]
# ### Exercise 6

# %% [markdown]
# Here are the SQL queries :
#
# 1. To select only the email addresses from the table:
# ```sql
# SELECT email FROM gameUser;
# ```
# (688 total, Query took 0.0006 seconds.)
#
# 2. To select all users where their `gamerscore` exceeds 9000:
# ```sql
# SELECT * FROM gameUser WHERE gamerscore > 9000;
# ```
# (677 total, Query took 0.0012 seconds.)
#
# 3. To select all users where their `gamerscore` exceeds 9000, ordering the results based on this `gamerscore`:
# ```sql
# SELECT * FROM gameUser WHERE gamerscore > 9000 ORDER BY gamerscore DESC;
# ```
# (677 total, Query took 0.0016 seconds.) [gamerscore: 80000... - 80000...]

# %% [markdown]
# ### Exercise 7

# %% [markdown]
# ```sql
#
# INSERT INTO gameUser (phone, name, email, address, country, region, postalzip, token, cash_spent, gamerscore)
# VALUES ('1234567890', 'Fake Me', 'fake.me@example.com', '123 Fake Street', 'Fakeland', 'Fakestate', 'FAKE123', 'tok1234567', 5000, 9500);
#
# ```
# - OUTPUT :  1 row inserted. Inserted row id: 5255634 (Query took 0.0055 seconds.)
#
# *Verifying -*
#
# ```sql
#
# SELECT * FROM gameUser WHERE id = 5255634;
#
# ```
# OUTPUT : Showing rows 0 - 0 (1 total, Query took 0.0013 seconds.)
# Full texts
# id - 5255634, phone - 1234567890, name - Fake Me, email - fake.me@example.com, address - 123 Fake Street, country - Fakeland, region - Fakestate, postalzip - FAKE123, token - tok1234567, cash_spent - 5000, gamerscore - 9500

# %% [markdown]
# ### Exercise 8

# %% [markdown]
# #### Modifying my fabricated record -
#
# ```sql
#
# UPDATE gameUser
# SET gamerscore = 12000, cash_spent = 3000, phone = '9876543210'
# WHERE id = 5255634;
#
# ```
#  1 row affected. (Query took 0.0033 seconds.)
#
# Verifying :
#
# ```sql
# SELECT * FROM gameUser WHERE id = 5255634;
# ```
# id - 5255634, phone - 9876543210, name - Fake Me, email - fake.me@example.com, address - 123 Fake Street, country - Fakeland, region - Fakestate, postalzip - FAKE123, token - tok1234567, cash_spent - 3000, gamerscore - 12000

# %% [markdown]
# ### Exercise 9

# %% [markdown]
# Firstly, Dry-Run -
#
# ```sql
#
# START TRANSACTION;
#
# DELETE FROM gameUser WHERE id = 5255634;
#
# -- To check how many rows would be affected
# SELECT ROW_COUNT();
#
# ROLLBACK;
#
#
# ```
#
# OUTPUT :  1 row affected. (Query took 0.0022 seconds.)
#
# So, I can actually run the query :
#
# ```sql
#
# DELETE FROM gameUser WHERE id = 5255634;
#
# ```
#
# OUTPUT : 1 row affected. (Query took 0.0033 seconds.)

# %% [markdown]
# ### Exercise 10

# %% [markdown]
# Installed pymysql and pony via PIP.

# %% [markdown]
# ### Exercise 11

# %%
from pony.orm import Database
db = Database()

# MySQL
db.bind(provider='mysql', host='europa.ashley.work', user='cetm50_user', passwd='iE93F2@8EhM@1zhD&u9M@K', db='cetm50')

# %% [markdown]
# ### Exercise 12

# %%
from pony.orm import Database
from pony.orm import db_session
db = Database()

# MySQL
db.bind(provider='mysql', host='europa.ashley.work', user='cetm50_user', passwd='iE93F2@8EhM@1zhD&u9M@K', db='cetm50')


with db_session:
    my_query_result = db.select("SELECT * FROM gameUser LIMIT 10;")
    

print(len(my_query_result))
print(my_query_result)
# Out:
# 10
# [(1, '99876555787655', 'Christopher', 'johndoe@gmail.com', '198 Condercum Road Benwell', 'United Kingdom', 'Sunderland', 'NE4 9JD', '5688977dsd', '1000', 80000), (2, '99876555787655', 'Anna Walker', 'johndoe@gmail.com', '57258 Cooper Parks Suite 894, South Michael, OK 56661', 'Maldives', 'Ohio', '53745', '5688977dsd', '1000', 80000), (3, '99876555787655', 'Taylor Ashley', 'johndoe@gmail.com', '98257 William Park Suite 045, South Victoriaside, PR 39648', 'Israel', 'Hawaii', '32526', '5688977dsd', '1000', 80000), (4, '99876555787655', 'Robert Zamora', 'johndoe@gmail.com', '11504 Jesus Dam Suite 190, Albertberg, CT 22146', 'United States of America', 'Wisconsin', '87803', '5688977dsd', '1000', 80000), (5, '99876555787655', 'Thomas Wood', 'johndoe@gmail.com', '76938 Patterson Road Apt. 424, Natalieberg, FL 79259', 'Haiti', 'New Jersey', '58686', '5688977dsd', '1000', 80000), (6, '99876555787655', 'Mark Wheeler', 'johndoe@gmail.com', '955 Amy Divide, New Ryanmouth, AS 67079', 'Israel', 'California', '90211', '5688977dsd', '1000', 80000), (7, '99876555787655', 'Tammy Guerra', 'johndoe@gmail.com', '4961 Ryan Cliff Suite 659, New Jennifer, AL 14928', 'Ghana', 'Arizona', '69437', '5688977dsd', '1000', 80000), (8, '99876555787655', 'Megan Robertson', 'johndoe@gmail.com', '1265 Megan Squares, Rodriguezmouth, VI 39527', 'Montserrat', 'Oklahoma', '38406', '5688977dsd', '1000', 80000), (9, '99876555787655', 'Diana Russell', 'johndoe@gmail.com', '0691 Valencia Vista Suite 395, North Oliviabury, DE 98115', 'Nicaragua', 'Idaho', '42722', '5688977dsd', '1000', 80000), (10, '99876555787655', 'Anna Ball', 'johndoe@gmail.com', 'PSC 8767, Box 5648, APO AE 41025', 'Fiji', 'South Dakota', '78793', '5688977dsd', '1000', 80000)]

# %% [markdown]
# ### Exercise 13

# %%
from pony.orm import Database, db_session

db = Database()
db.bind(provider='mysql', host='europa.ashley.work', user='cetm50_user', passwd='iE93F2@8EhM@1zhD&u9M@K', db='cetm50')

# Query 1 :

with db_session:
    cursor = db.execute("""
        SELECT 
            MAX(LENGTH(id)) AS MaxIdLength,
            MAX(LENGTH(phone)) AS MaxPhoneLength,
            MAX(LENGTH(name)) AS MaxNameLength,
            MAX(LENGTH(email)) AS MaxEmailLength,
            MAX(LENGTH(address)) AS MaxAddressLength,
            MAX(LENGTH(country)) AS MaxCountryLength,
            MAX(LENGTH(region)) AS MaxRegionLength,
            MAX(LENGTH(postalzip)) AS MaxPostalZipLength,
            MAX(LENGTH(token)) AS MaxTokenLength
        FROM gameUser;
    """)
    max_lengths = cursor.fetchone()
    print(max_lengths)

    
    
# Query 2: Select Email Addresses

with db_session:
    emails = db.select("SELECT email FROM gameUser;")
    print(emails)

    
# Query 3: Select Users with Gamerscore Over 9000

with db_session:
    high_score_users = db.select("SELECT * FROM gameUser WHERE gamerscore > 9000;")
    print(high_score_users)

    
# Query 4: Order Users by Gamerscore
  
with db_session:
    ordered_high_score_users = db.select("SELECT * FROM gameUser WHERE gamerscore > 9000 ORDER BY gamerscore DESC;")
    print(ordered_high_score_users)

    
# Query 5: Insert Fabricated Data

user_data = {
    'phone': '1234567890',
    'name': 'Fake Me',
    'email': 'fake.me@example.com',
    'address': '123 Fake Street',
    'country': 'Fakeland',
    'region': 'Fakestate',
    'postalzip': 'FAKE123',
    'token': 'tok1234567',
    'cash_spent': 5000,
    'gamerscore': 9500
}


with db_session:
    db.execute(f"""
        INSERT INTO gameUser (phone, name, email, address, country, region, postalzip, token, cash_spent, gamerscore)
        VALUES ('{user_data['phone']}', '{user_data['name']}', '{user_data['email']}', '{user_data['address']}', 
        '{user_data['country']}', '{user_data['region']}', '{user_data['postalzip']}', '{user_data['token']}', 
        {user_data['cash_spent']}, {user_data['gamerscore']});
    """)


    
# Query 6: Select User by ID

with db_session:
    user_by_id = db.select("SELECT * FROM gameUser WHERE id = 5255634;")
    print(user_by_id)

    
# Query 7: Update User Record

with db_session:
    db.execute("UPDATE gameUser SET gamerscore = 12000, cash_spent = 3000, phone = '9876543210' WHERE id = 5255634;")

    
# Query 8: Select Updated User by ID

with db_session:
    updated_user_by_id = db.select("SELECT * FROM gameUser WHERE id = 5255634;")
    print(updated_user_by_id)

    
# Query 9: Delete User Record

with db_session:
    db.execute("DELETE FROM gameUser WHERE id = 5255634;")
# Out:
# (7, 17, 25, 31, 60, 51, 21, 9, 38)
# ['johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe@gmail.com', 'johndoe
on Brown', 'johndoe@gmail.com', '635 Pittman Ramp, Michaelberg, NC 75096', 'Christmas Island', 'North Dakota', '37247', '5688977dsd', '1000', 80000), (16, '99876555787655', 'Cheryl Rogers', 'johndoe@gmail.com', '96341 Adam Port, Lake Matthew, OH 08935', 'Iraq', 'Georgia', '96588', '5688977dsd', '1000', 80000), (17, '99876555787655', 'Tony Wheeler', 'johndoe@gmail.com', '256 Lewis Springs Suite 320, Blankenshipmouth, GA 25131', 'Honduras', 'Arkansas', '67014', '5688977dsd', '1000', 80000), (18, '99876555787655', 'Kimberly Reeves', 'johndoe@gmail.com', '06111 Michelle Fall Apt. 061, Gabrielaville, DE 82101', 'Cameroon', 'Ohio', '38819', '5688977dsd', '1000', 80000), (19, '99876555787655', 'Richard Murray', 'johndoe@gmail.com', '003 Reed Circle, Port Renee, WI 02487', 'Bermuda', 'Arizona', '05179', '5688977dsd', '1000', 80000), (20, '99876555787655', 'Bruce Hubbard', 'johndoe@gmail.com', '04224 Jessica Parkway Suite 184, Stevensfort, GA 30971', 'Serbia', 'Arkansas', '06294', '5688977dsd', '1000', 80000), (21, '99876555787655', 'Jenny Smith', 'johndoe@gmail.com', '5804 Donna Islands Suite 944, Alexanderville, FL 03652', 'Martinique', 'Alabama', '03707', '5688977dsd', '1000', 80000), (22, '99876555787655', 'Jorge Price', 'johndoe@gmail.com', 'Unit 0223 Box 9661, DPO AP 88247', 'Ethiopia', 'Nebraska', '67647', '5688977dsd', '1000', 80000), (23, '99876555787655', 'Tanner Boone', 'johndoe@gmail.com', '158 Fuller Ridge, South Josephland, AS 62175', 'Estonia', 'Missouri',  ...
# [(256, '99876555787655', 'Jenna Porter', 'johndoe@gmail.com', '9835 Aaron Junction Apt. 747, North Danielle, VA 13947', 'Cuba', 'Kentucky', '60456', '5688977dsd', '1000', 80000), (512, '99876555787655', 'Clayton Walker', 'johndoe@gmail.com', '886 Jeffery Islands Suite 900, Andreshaven, VA 58593', 'Hungary', 'Nevada', '74806', '5688977dsd', '1000', 80000), (98816, '99876555787655', 'John Doe', 'johndoe@gmail.com', '123 Main St', 'USA', 'North', '12345', '5688977dsd', '1000', 80000), (1, '99876555787655', 'Christopher', 'johndoe@gmail.com', '198 Condercum Road Benwell', 'United Kingdom', 'Sunderland', 'NE4 9JD', '5688977dsd', '1000', 80000), (257, '99876555787655', 'Alex Duran', 'johndoe@gmail.com', 'Unit 9668 Box 6201, DPO AE 48500', 'Central African Republic', 'North Carolina', '56088', '5688977dsd', '1000', 80000), (513, '99876555787655', 'David Johnson', 'johndoe@gmail.com', '3539 David Vista Apt. 922, South Shannon, NY 18435', 'Holy See (Vatican City State)', 'New Jersey', '76978', '5688977dsd', '1000', 80000), (2, '99876555787655', 'Anna Walker', 'johndoe@gmail.com', '57258 Cooper Parks Suite 894, South Michael, OK 56661', 'Maldives', 'Ohio', '53745', '5688977dsd', '1000', 80000), (258, '99876555787655', 'Kathy Taylor', 'johndoe@gmail.com', '04980 Boyle Lodge Suite 150, Virginiahaven, VA 36127', 'India', 'Ohio', '04026', '5688977dsd', '1000', 80000), (514, '99876555787655', 'Julie Mason', 'johndoe@gmail.com', '37214 Paige Circle, Hinesburgh, VI 34971', 'Syrian Arab Republic', 'Michigan', '39097', '5688977dsd', '1000', 80000), (98818, '99876555787655', 'John Doe', 'johndoe@gmail.com', '123 Main St', 'USA', 'West', '12345', '5688977dsd', '1000', 80000), (3, '99876555787655', 'Taylor Ashley', 'johndoe@gmail.com', '98257 William Park Suite 045, South Victoriaside, PR 39648', 'Israel', 'Hawaii', '32526', '5688977dsd', '1000', 80000), (259, '99876555787655', 'Teresa Martinez', 'johndoe@gmail.com', '00218 Torres Terrace Apt. 479, Markland, NM 63381', 'New Caledonia', 'New York', '83227', '5688977dsd', '1000', 80000), (515, '99876555787655', 'Devin Leblanc', 'johndoe@gmail.com', '75330 Wise Center, South Kelseychester, WA 16303', 'Antarctica (the territory South of 60 deg S)', 'Nevada', '44364', '5688977dsd', '1000', 80000), (98819, '99876555787655', 'John Doe', 'johndoe@gmail.com', '123 Main St', 'USA', 'West', '12345', '5688977dsd', '1000', 80000), (4, '99876555787655', 'Robert Zamora', 'johndoe@gmail.com', '11504 Jesus Dam Suite 190, Albertberg, CT 22146', 'United States of America', 'Wisconsin', '87803', '5688977dsd', '1000', 80000), (260, '99876555787655', 'Sabrina Berry', 'johndoe@gmail.com', 'Unit 5162 Box 6689, DPO AA 04785', 'Sao Tome and Principe', 'Virginia', '84789', '5688977dsd', '1000', 80000), (516, '99876555787655', 'Lauren Stark', 'johndoe@gmail.com', '64387 Jorge Streets Suite 710, New Ryan, NE 06741', 'Iceland', 'California', '01777', '5688977dsd', '1000', 80000), (98820, '99876555787655', 'John Doe', 'johndoe@gmail.com', '123 Main St', 'USA', 'West', '12345', '5688977dsd', '1000', 80000), (836612, '99876555787655', 'Adekunle John', 'Adekunle.john@gmail.com', 'Flat 51', 'Uited Kingdom', 'Tyne and Wear', 'Sr1 1ee', '5688977dsd', '1000', 80000), (5, '99876555787655', 'Thomas Wood', 'johndoe@gmail.com', '76938 Patterson Road Apt. 424, Natalieberg, FL 79259', 'Haiti', 'New Jersey', '58686', '5688977dsd', '1000', 80000), (261, '99876555787655', 'Debra Jackson', 'johndoe@gmail.com', '269 Frazier Union, Jennyfort, AS 65563', 'Tonga', 'Arkansas', '58862', '5688977dsd', '1000', 80000), (517, '99876555787655', 'Joseph Williams', 'johndoe@gmail.com', 'PSC 8054, Box 6265, APO AA 91601', 'Poland', 'Arizona', '14026', '5688977dsd', '1000', 80000), (98821, '99876555787655', 'John Doe', 'johndoe@gmail.com', '123 Main St', 'USA', 'West', '12345', '5688977dsd', '1000', 80000), (6, '99876555787655', 'Mark Wheeler', 'johndoe@gmail.com', '955 Amy Divide, New Ryanmouth, AS 67079', 'Israel', 'California', '90211', '5688977dsd', '1000' ...
# []
# []
